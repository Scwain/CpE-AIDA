# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pov_sales = pd.read_excel('58021_CS5(Q1) Dataset Development_DDS.xlsx')
pov_sales2 = pd.read_csv('58021_CS5(Q1)DatasetDevelopment_DDS.csv')
pov_sales
# Out:
#     Count Number                                    Platform  North America  \
# 0            1.0                         PlayStation 2 (PS2)          53.65
# 1            2.0                            Nintendo DS (DS)          57.39
# 2            3.0                               Game Boy (GB)          43.18
# 3            4.0                         PlayStation 4 (PS4)          38.63
# 4            5.0                        Nintendo Switch (NS)          39.20
# 5            6.0                            PlayStation (PS)          40.78
# 6            7.0                                   Wii (Wii)          45.51
# 7            8.0                         PlayStation 3 (PS3)          29.42
# 8            9.0                             Xbox 360 (X360)          49.11
# 9           10.0                      Game Boy Advance (GBA)          40.39
# 10          11.0                  PlayStation Portable (PSP)          21.41
# ...

# %%
pov_sales.head()
# Out:
#    Count Number              Platform  North America  Europe  Japan  \
# 0           1.0   PlayStation 2 (PS2)          53.65   55.28  23.18
# 1           2.0      Nintendo DS (DS)          57.39   52.07  33.01
# 2           3.0         Game Boy (GB)          43.18   40.05  32.47
# 3           4.0   PlayStation 4 (PS4)          38.63   48.74   9.39
# 4           5.0  Nintendo Switch (NS)          39.20   28.13  24.42
#
#    Rest of the World  Global
# 0              25.57  157.68
# 1              12.43  154.90
# 2               2.99  118.69
# 3              20.17  116.93
# 4              14.76  106.51

# %%
pov_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Count Number       36 non-null     float64
#  1   Platform           36 non-null     object
#  2   North America      36 non-null     float64
#  3   Europe             36 non-null     float64
#  4   Japan              36 non-null     float64
#  5   Rest of the World  36 non-null     float64
#  6   Global             36 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 2.1+ KB

# %%
pov_sales.dropna()
# Out:
#     Count Number                                    Platform  North America  \
# 0            1.0                         PlayStation 2 (PS2)          53.65
# 1            2.0                            Nintendo DS (DS)          57.39
# 2            3.0                               Game Boy (GB)          43.18
# 3            4.0                         PlayStation 4 (PS4)          38.63
# 4            5.0                        Nintendo Switch (NS)          39.20
# 5            6.0                            PlayStation (PS)          40.78
# 6            7.0                                   Wii (Wii)          45.51
# 7            8.0                         PlayStation 3 (PS3)          29.42
# 8            9.0                             Xbox 360 (X360)          49.11
# 9           10.0                      Game Boy Advance (GBA)          40.39
# 10          11.0                  PlayStation Portable (PSP)          21.41
# ...

# %%
pov_sales.describe()
# Out:
#        Count Number  North America     Europe      Japan  Rest of the World  \
# count     36.000000      36.000000  36.000000  36.000000          36.000000
# mean      18.500000      19.491111  13.941667   8.411944           4.405278
# std       10.535654      18.309539  16.605470  10.250585           6.482263
# min        1.000000       0.000000   0.000000   0.000000           0.000000
# 25%        9.750000       2.437500   0.840000   0.090000           0.052500
# 50%       18.500000      16.375000   6.760000   3.455000           0.915000
# 75%       27.250000      34.775000  24.775000  17.012500           6.392500
# max       36.000000      57.390000  55.280000  33.010000          25.570000
#
#            Global
# count   36.000000
# mean    46.250000
# std     47.713584
# min      0.000000
# 25%      7.225000
# 50%     26.145000
# 75%     82.582500
# max    157.680000

# %%
new_pov_sales = pov_sales.sort_values ('Platform', ascending = False)
new_pov_sales
# Out:
#     Count Number                                    Platform  North America  \
# 34          35.0                                   iOS (iOS)           0.00
# 23          24.0                        Xbox Series X/S (XS)           7.49
# 13          14.0                             Xbox One (XOne)          32.47
# 8            9.0                             Xbox 360 (X360)          49.11
# 18          19.0                                   Xbox (XB)          15.77
# 28          29.0                             WonderSwan (WS)           0.00
# 22          23.0                                Wii U (WiiU)           6.23
# 6            7.0                                   Wii (Wii)          45.51
# 35          36.0                        TurboGrafx-16 (TG16)           0.00
# 14          15.0  Super Nintendo Entertainment System (SNES)          22.88
# 25          26.0                           Sega Saturn (SAT)           1.83
# ...

# %%
imp_data = new_pov_sales[['Platform', 'North America', 'Europe', 'Japan', 'Rest of the World','Global']]
imp_data.sort_values('Platform', ascending = True)
# Out:
#                                       Platform  North America  Europe  Japan  \
# 29           3DO Interactive Multiplayer (3DO)           0.00    0.00   0.00
# 17                           Atari 2600 (2600)          23.54    3.35   0.00
# 27                           Atari 7800 (7800)           4.30    0.00   0.00
# 26                              Dreamcast (DC)           3.90    1.91   2.25
# 2                                Game Boy (GB)          43.18   40.05  32.47
# 9                       Game Boy Advance (GBA)          40.39   21.31  16.96
# 19                               GameCube (GC)          12.55    4.44   4.04
# 24                               GameGear (GG)           5.40    3.23   1.78
# 33                      Microsoft Windows (PC)           0.00    0.00   0.00
# 30                                Neo Geo (NG)           0.00    0.00   0.00
# 11                          Nintendo 3DS (3DS)          25.77   21.07  24.67
# ...

# %%
imp_data.plot(kind = 'bar')
plt.title ('Total platform sales with respect to countries', size = 80) 
plt.rcParams["axes.labelsize"] = 30
plt.bar
fig = plt.gcf()
fig.set_size_inches(80, 20)
plt.show()
